# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/CRUD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

def connect_db():
    return sqlite3.connect("students.db")

def create_table():
    conn = connect_db()
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS students (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT NOT NULL,
            age INTEGER,
            grade TEXT
        )
    """)
    conn.commit()
    conn.close()

def insert_student():
    name = input("Enter Name: ")
    age = int(input("Enter Age: "))
    grade = input("Enter Grade: ")

    conn = connect_db()
    cursor = conn.cursor()
    cursor.execute(
        "INSERT INTO students (name, age, grade) VALUES (?, ?, ?)",
        (name, age, grade)
    )
    conn.commit()
    conn.close()
    print("✅ Student added successfully.\n")

def view_students():
    conn = connect_db()
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM students")
    rows = cursor.fetchall()
    conn.close()

    if rows:
        print("\n--- Student Records ---")
        for row in rows:
            print(f"ID: {row[0]}, Name: {row[1]}, Age: {row[2]}, Grade: {row[3]}")
        print()
    else:
        print("⚠ No records found.\n")

def update_student():
    student_id = int(input("Enter Student ID to update: "))
    new_grade = input("Enter New Grade: ")

    conn = connect_db()
    cursor = conn.cursor()
    cursor.execute(
        "UPDATE students SET grade = ? WHERE id = ?",
        (new_grade, student_id)
    )
    conn.commit()
    conn.close()
    print("✅ Student updated successfully.\n")

def delete_student():
    student_id = int(input("Enter Student ID to delete: "))

    conn = connect_db()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM students WHERE id = ?", (student_id,))
    conn.commit()
    conn.close()
    print("✅ Student deleted successfully.\n")

def main():
    create_table()

    while True:
        print("===== STUDENT DATABASE MENU =====")
        print("1. Insert Student")
        print("2. View Students")
        print("3. Update Student")
        print("4. Delete Student")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            insert_student()
        elif choice == '2':
            view_students()
        elif choice == '3':
            update_student()
        elif choice == '4':
            delete_student()
        elif choice == '5':
            print("Exiting program...")
            break
        else:
            print("Invalid choice! Try again.\n")

if __name__ == "__main__":
    main()
# Out:
# ===== STUDENT DATABASE MENU =====
# 1. Insert Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice (1-5): 1
# Enter Name: roshan
# Enter Age: 21
# Enter Grade: 8.5
# ✅ Student added successfully.
#
# ===== STUDENT DATABASE MENU =====
# 1. Insert Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice (1-5): 1
# Enter Name: abhinav
# Enter Age: 2
# Enter Grade: 8.0
# ✅ Student added successfully.
#
# ===== STUDENT DATABASE MENU =====
# 1. Insert Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Exit
# Enter your choice (1-5): 5
# Exiting program...
