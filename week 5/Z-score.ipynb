# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/week%205/Z-score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#z-score
import numpy as np
data = [10,20,30,40,50]
mean = np.mean(data)
print("Mean", mean)
std_dev=np.std(data, ddof= 1)
print("Standard deviation", std_dev)
x_mean = 40
z_score = (x_mean)/std_dev
print("Z-score of 20", z_score)
z_score = [(x_mean/std_dev for x in data)]
print("Z-score of data", z_score)
# Out:
# Mean 30.0
# Standard deviation 15.811388300841896
# Z-score of 20 2.5298221281347035
# Z-score of data [<generator object <genexpr> at 0x7ddf98a54520>]
