# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/week%205/central%20limit%20theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#central limit theorem
import numpy as np

# Population data
population = np.array([11,22,33,44,5,66,77])


mu = np.mean(population)
print("Population Mean:", mu)


sigma = np.std(population)
print("Population Standard Deviation:", sigma)

num_samples = 1000
sample_size = 3

sample_means = []

for i in range(num_samples):
    sample = np.random.choice(population, sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

mean_sample_means = np.mean(sample_means)

print("Mean of Sample Means:", mean_sample_means)
# Out:
# Population Mean: 36.857142857142854
# Population Standard Deviation: 25.15908567171579
# Mean of Sample Means: 36.48
