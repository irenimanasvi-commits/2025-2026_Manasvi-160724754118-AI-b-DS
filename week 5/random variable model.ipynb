# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/week%205/random%20variable%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#random variable model
import numpy as np

# Random variable data
X = np.array([1,2,3,4,5,6,7])

# Number of observations
n = len(X)
print("Total observations:", n)

# Probability of each value (discrete random variable)
p = 1/n

print("\nRandom Variable Values and Probabilities:")
for x in X:
    print("P(X =", x, ") =", p)

# Expected value E(X)
EX = np.sum(X * p)
print("\nExpected Value E(X):", EX)

# Variance Var(X)
variance = np.sum(((X - EX)**2) * p)
print("Variance Var(X):", variance)

# Standard Deviation
std = np.sqrt(variance)
print("Standard Deviation:", std)
# Out:
# Total observations: 7
#
# Random Variable Values and Probabilities:
# P(X = 1 ) = 0.14285714285714285
# P(X = 2 ) = 0.14285714285714285
# P(X = 3 ) = 0.14285714285714285
# P(X = 4 ) = 0.14285714285714285
# P(X = 5 ) = 0.14285714285714285
# P(X = 6 ) = 0.14285714285714285
# P(X = 7 ) = 0.14285714285714285
#
# Expected Value E(X): 3.9999999999999996
# Variance Var(X): 4.0
# Standard Deviation: 2.0
