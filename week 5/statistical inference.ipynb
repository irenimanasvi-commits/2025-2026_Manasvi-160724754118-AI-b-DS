# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/week%205/statistical%20inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#statistical inference
import numpy as np
import math
population=np.array([10,20,30,40,50,60,70])
N=len (population)
print("population size(N):",N)
mu=np.mean(population)
print("population mean(u):",mu)
sigma2=np.var(population,ddof=0)
print("population variance(sigma^2):",sigma2)
sigma=np.sqrt(sigma2)
print("population standard deviation:",sigma2)
sample=np.array([20,30,40,50])
n=len(sample)
print("\n sample size(n):",n)
x_bar=np.mean(sample)
print("sample mean:",x_bar)
s2=np.var(sample,ddof=1)
print("sample variance:",s2)
s=np.sqrt(s2)
print("sample standard deviation(s):",s)
SE=sigma/math.sqrt(n)
print("\n standard error:",SE)
z=(x_bar-mu)/SE
print("z-score:",z)
# Out:
# population size(N): 7
# population mean(u): 40.0
# population variance(sigma^2): 400.0
# population standard deviation: 400.0
#
#  sample size(n): 4
# sample mean: 35.0
# sample variance: 166.66666666666666
# sample standard deviation(s): 12.909944487358056
#
#  standard error: 10.0
# z-score: -0.5
