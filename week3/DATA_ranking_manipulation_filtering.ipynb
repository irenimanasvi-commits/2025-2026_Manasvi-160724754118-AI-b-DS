# %% [markdown]
# <a href="https://colab.research.google.com/github/irenimanasvi-commits/2025-2026_Manasvi-160724754118-AI-b-DS/blob/main/DATA_ranking_manipulation_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data filtering
import pandas as pd

data = {
    "ID": [101, 102, 103, 104, 105],
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [22, 25, 23, 24, 26],
    "Marks": [85, 78, 92, 88, 90]
}

df = pd.DataFrame(data)

print("Original Dataframe:")
print(df)

print("\n Students with marks >85:")
print(df[df["Marks"] > 85])

print("\n student with age <25:")
print(df[df["Age"] < 25])

print(df[(df["Age"] > 23) & (df["Marks"] > 88)])
print(df[df["Marks"] > 90], df["Age"] > 23)
# Out:
# Original Dataframe:
#     ID     Name  Age  Marks
# 0  101    Alice   22     85
# 1  102      Bob   25     78
# 2  103  Charlie   23     92
# 3  104    David   24     88
# 4  105      Eva   26     90
#
#  Students with marks >85:
#     ID     Name  Age  Marks
# 2  103  Charlie   23     92
# 3  104    David   24     88
# 4  105      Eva   26     90
#
#  student with age <25:
#     ID     Name  Age  Marks
# 0  101    Alice   22     85
# 2  103  Charlie   23     92
# 3  104    David   24     88
#     ID Name  Age  Marks
# 4  105  Eva   26     90
#     ID     Name  Age  Marks
# 2  103  Charlie   23     92 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Age, dtype: bool

# %%
# Data Manipulation
import pandas as pd

# create Dataframe
data = {
    "Name": ["A", "B", "C"],
    "Age": [20, 21, 22],
    "Marks": [70, 80, 90]
}

df = pd.DataFrame(data)

print("Original Data:")
print(df)

# Add new column
df["Bonus"] = 5
print("\n After adding Bonus:")
print(df)

# Increase marks
df["Marks"] = df["Marks"] + 2
print("\n After increasing marks")
print(df)

# Change value
df.loc[0, "Age"] = 21
print("\n After changing age of first student:")
print(df)

# Rename column
df.rename(columns={"total": "final"}, inplace=True)
print("\n After renaming total to final:")
print(df)

# Remove column
df.drop("Bonus", axis=1, inplace=True)
print("\n After removing Bonus:")
print(df)
# Out:
# Original Data:
#   Name  Age  Marks
# 0    A   20     70
# 1    B   21     80
# 2    C   22     90
#
#  After adding Bonus:
#   Name  Age  Marks  Bonus
# 0    A   20     70      5
# 1    B   21     80      5
# 2    C   22     90      5
#
#  After increasing marks
#   Name  Age  Marks  Bonus
# 0    A   20     72      5
# 1    B   21     82      5
# 2    C   22     92      5
#
#  After changing age of first student:
#   Name  Age  Marks  Bonus
# 0    A   21     72      5
# 1    B   21     82      5
# 2    C   22     92      5
#
#  After renaming total to final:
#   Name  Age  Marks  Bonus
# 0    A   21     72      5
# 1    B   21     82      5
# 2    C   22     92      5
#
#  After removing Bonus:
#   Name  Age  Marks
# 0    A   21     72
# 1    B   21     82
# 2    C   22     92

# %%
# Ranking

import pandas as pd

data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [85, 92, 78, 80]
}

df = pd.DataFrame(data)

print("Original Data:")
print(df)

df["Rank"] = df["Marks"].rank(ascending=False)

print("\nAfter ranking:")
print(df)
# Out:
# Original Data:
#   Name  Marks
# 0    A     85
# 1    B     92
# 2    C     78
# 3    D     80
#
# After ranking:
#   Name  Marks  Rank
# 0    A     85   2.0
# 1    B     92   1.0
# 2    C     78   4.0
# 3    D     80   3.0
